# %% [markdown]
# ## ◢ Installation

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %pwd

# %%
# 경로 수정
# %cd inference/textual_inversion

# %%
# !pip install -r requirements.txt --quiet

# %%
# !pip install colab-xterm --quiet

# %% [markdown]
# ----
#
# ## ◢ Execution

# %%
# %pwd

# %%
# !python scripts/stable_txt2img.py -h

# %%
# !mkdir -p ./outputs/test00

# %%
prompt = "" # 프롬프트 입력

with open("./prompt00.txt", 'w') as f:
    f.write(prompt)

# %%
# !python scripts/stable_txt2img.py --ddim_eta 0.0 \
                                  --n_samples 1 \
                                  --n_iter 1 \
                                  --scale 14.0 \
                                  --seed 3076569961 \
                                  --embedding_path ./embeddings/marnie/learned_embeds.bin \
                                  --from-file ./prompt00.txt \
                                  --outdir ./outputs/test00
